# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/recruitment_data.csv")
df
# Out:
#       Age  Gender  EducationLevel  ExperienceYears  PreviousCompanies  \
# 0      26       1               2                0                  3
# 1      39       1               4               12                  3
# 2      48       0               2                3                  2
# 3      34       1               2                5                  2
# 4      30       0               1                6                  1
# ...   ...     ...             ...              ...                ...
# 1495   48       0               2                3                  4
# 1496   27       1               2               10                  3
# 1497   24       1               1                1                  2
# 1498   48       0               2                4                  4
# 1499   34       1               2               11                  5
#
#       DistanceFromCompany  InterviewScore  SkillScore  PersonalityScore  \
# 0               26.783828              48          78                91
# 1               25.862694              35          68                80
# 2                9.920805              20          67                13
# 3                6.407751              36          27                70
# 4               43.105343              23          52                85
# ...                   ...             ...         ...               ...
# 1495             9.183783              66           3                80
# 1496            14.847731              43          97                 7
# 1497             4.289911              31          91                58
# 1498            36.299263               9          37                44
# 1499            12.910472              63          40                26
#
#       RecruitmentStrategy  HiringDecision
# 0                       1               1
# 1                       2               1
# 2                       2               0
# 3                       3               0
# 4                       2               0
# ...                   ...             ...
# 1495                    3               1
# 1496                    2               0
# 1497                    1               1
# 1498                    2               1
# 1499                    2               1
#
# [1500 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
X = df.drop('HiringDecision',axis=1)
y = df['HiringDecision']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
X_train
# Out:
#       Age  Gender  EducationLevel  ExperienceYears  PreviousCompanies  \
# 729    40       1               1                7                  2
# 510    41       1               1                2                  3
# 100    31       0               1                2                  1
# 1054   41       0               1               15                  1
# 1055   41       1               3               13                  3
# ...   ...     ...             ...              ...                ...
# 1417   23       1               1               13                  2
# 75     34       0               2               14                  5
# 599    49       0               3                6                  2
# 1361   31       0               1                9                  2
# 863    48       1               2               14                  2
#
#       DistanceFromCompany  InterviewScore  SkillScore  PersonalityScore  \
# 729              6.361120              27          63                37
# 510             15.822244              72          71                 3
# 100             36.953781              66          27                76
# 1054             4.946493              96          59                79
# 1055            10.583566              20           8                80
# ...                   ...             ...         ...               ...
# 1417            11.413884              76          57                63
# 75               3.046697              67          38                86
# 599             17.911548              25          46                45
# 1361            23.339184              31          82                 2
# 863             35.489562              80          99                94
#
#       RecruitmentStrategy
# 729                     2
# 510                     1
# 100                     1
# 1054                    1
# 1055                    2
# ...                   ...
# 1417                    2
# 75                      1
# 599                     3
# 1361                    1
# 863                     1
#
# [1050 rows x 10 columns]

# %%
from xgboost import XGBClassifier

bst = XGBClassifier(n_estimators=500, max_depth=7, learning_rate=0.01, objective='binary:logistic')
# fit model
bst.fit(X_train, y_train)
# make predictions
preds = bst.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, preds)
# Out:
# 0.9355555555555556

# %%
import pickle

# %%
filename = 'finalized_model.sav'
pickle.dump(bst, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# 0.9355555555555556
